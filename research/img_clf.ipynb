# %%
import os
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from PIL import Image
import shutil
import numpy as np
import matplotlib.pyplot as plt

os.chdir("..")
os.getcwd()

# %%
from src.imgclf.load import load_img

# %%
ds_train, ds_val = load_img.load_imgs_from_dir()
# Out:
# Found 55196 images belonging to 10 classes.
# Found 13795 images belonging to 10 classes.

# %%
load_img.dataset_info(ds_train)
# Out:
# shape of a single batch (batch size, height, width, no. channels): (32, 28, 28, 3)
# max value: 1.0, min value: 0.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28, 3)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10)
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# %%
model.fit(
    ds_train,
    epochs=6,
    validation_data=ds_val,
)
# Out:
# Epoch 1/6
# WARNING:tensorflow:From d:\PycharmProjects\image-classification\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1725/1725 [==============================] - 15s 9ms/step - loss: 0.2206 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.1345 - val_sparse_categorical_accuracy: 0.9598
# Epoch 2/6
# 1725/1725 [==============================] - 14s 8ms/step - loss: 0.1016 - sparse_categorical_accuracy: 0.9690 - val_loss: 0.1100 - val_sparse_categorical_accuracy: 0.9676
# Epoch 3/6
# 1725/1725 [==============================] - 14s 8ms/step - loss: 0.0714 - sparse_categorical_accuracy: 0.9777 - val_loss: 0.0795 - val_sparse_categorical_accuracy: 0.9762
# Epoch 4/6
# 1725/1725 [==============================] - 14s 8ms/step - loss: 0.0534 - sparse_categorical_accuracy: 0.9824 - val_loss: 0.0984 - val_sparse_categorical_accuracy: 0.9695
# Epoch 5/6
# 1725/1725 [==============================] - 15s 9ms/step - loss: 0.0417 - sparse_categorical_accuracy: 0.9864 - val_loss: 0.0906 - val_sparse_categorical_accuracy: 0.9745
# Epoch 6/6
# 1725/1725 [==============================] - 14s 8ms/step - loss: 0.0346 - sparse_categorical_accuracy: 0.9880 - val_loss: 0.0827 - val_sparse_categorical_accuracy: 0.9770
